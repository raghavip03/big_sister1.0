# %%
! pip install gpt_index

# %%
! pip install langchain

# %%
! pip install --upgrade openai llama_index

# %%
from langchain.llms import OpenAI

# %%
from llama_index import SimpleDirectoryReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/raghaviputluri/Desktop/big_sister1.0/test.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/raghaviputluri/Desktop/big_sister1.0/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from llama_index import SimpleDirectoryReader
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/__init__.py:21
#      18 from llama_index.embeddings.openai import OpenAIEmbedding
#      20 # structured
# ---> 21 from llama_index.indices.common.struct_store.base import SQLDocumentContextBuilder
#      23 # for composability
#      24 from llama_index.indices.composability.graph import ComposableGraph
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/indices/__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ...
